# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj-inbetween/AstraDB-Example-Code/blob/main/RAGStackColBERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ColBERT in RAGStack with Astra
#
# This notebook illustrates steps using RAGStack to
#
# 1.   Create ColBERT embedding
# 2.   Index embeddings on Astra
# 3.   Retrieve with RAGStack and Astra
#
# * Use the LangChain ColBERT plugin
#
# ColBERT paper: https://arxiv.org/abs/2004.12832

# %% [markdown]
# ## set up
# Let's import RAGStack-ColBERT

# %%
# !pip install ragstack-ai-colbert
# Out:
# Collecting ragstack-ai-colbert
#   Downloading ragstack_ai_colbert-1.0.1-py3-none-any.whl (24 kB)
# Collecting cassio<0.2.0,>=0.1.7 (from ragstack-ai-colbert)
#   Downloading cassio-0.1.7-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.7 MB/s eta 0:00:00
# Collecting colbert-ai==0.2.19 (from ragstack-ai-colbert)
#   Downloading colbert-ai-0.2.19.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-colbert) (1.6.0)
# Collecting pyarrow==14.0.1 (from ragstack-ai-colbert)
#   Downloading pyarrow-14.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (38.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 36.2 MB/s eta 0:00:00
# Requirement already satisfied: torch==2.2.1 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-colbert) (2.2.1+cu121)
# Collecting bitarray (from colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading bitarray-2.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 38.0 MB/s eta 0:00:00
# Collecting datasets (from colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 55.7 MB/s eta 0:00:00
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert) (2.2.5)
# Collecting git-python (from colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading git_python-1.0.3-py2.py3-none-any.whl (1.9 kB)
# Collecting python-dotenv (from colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting ninja (from colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 37.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert) (4.66.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert) (4.40.1)
# Collecting ujson (from colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading ujson-5.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow==14.0.1->ragstack-ai-colbert) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->ragstack-ai-colbert)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Collecting cassandra-driver<4.0.0,>=3.28.0 (from cassio<0.2.0,>=0.1.7->ragstack-ai-colbert)
#   Downloading cassandra_driver-3.29.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 68.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from cassio<0.2.0,>=0.1.7->ragstack-ai-colbert) (2.31.0)
# Collecting geomet<0.3,>=0.1 (from cassandra-driver<4.0.0,>=3.28.0->cassio<0.2.0,>=0.1.7->ragstack-ai-colbert)
#   Downloading geomet-0.2.1.post1-py3-none-any.whl (18 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->cassio<0.2.0,>=0.1.7->ragstack-ai-colbert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->cassio<0.2.0,>=0.1.7->ragstack-ai-colbert) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->cassio<0.2.0,>=0.1.7->ragstack-ai-colbert) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->cassio<0.2.0,>=0.1.7->ragstack-ai-colbert) (2024.2.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (2.0.3)
# Collecting xxhash (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (3.9.5)
# Collecting huggingface-hub>=0.21.2 (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 45.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (6.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask->colbert-ai==0.2.19->ragstack-ai-colbert) (3.0.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask->colbert-ai==0.2.19->ragstack-ai-colbert) (2.2.0)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask->colbert-ai==0.2.19->ragstack-ai-colbert) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.2.1->ragstack-ai-colbert) (2.1.5)
# Collecting gitpython (from git-python->colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 29.2 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.2.1->ragstack-ai-colbert) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->colbert-ai==0.2.19->ragstack-ai-colbert) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->colbert-ai==0.2.19->ragstack-ai-colbert) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->colbert-ai==0.2.19->ragstack-ai-colbert) (0.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (4.0.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from geomet<0.3,>=0.1->cassandra-driver<4.0.0,>=3.28.0->cassio<0.2.0,>=0.1.7->ragstack-ai-colbert) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython->git-python->colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->colbert-ai==0.2.19->ragstack-ai-colbert) (2024.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->git-python->colbert-ai==0.2.19->ragstack-ai-colbert)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: colbert-ai
#   Building wheel for colbert-ai (setup.py) ... done
#   Created wheel for colbert-ai: filename=colbert_ai-0.2.19-py3-none-any.whl size=114762 sha256=72c37cb68ede1d9d3eb410fb835889533219287ceb90ea5f5685f79570f89516
#   Stored in directory: /root/.cache/pip/wheels/90/b9/63/d4fc276c73c42ef7fc1065a26cf87e5a1cf56ef6498cbfbe5d
# Successfully built colbert-ai

# %% [markdown]
# Prepare documents including chunking

# %%
arctic_botany_dict = {
    "Introduction to Arctic Botany": "Arctic botany is the study of plant life in the Arctic, a region characterized by extreme cold, permafrost, and minimal sunlight for much of the year. Despite these harsh conditions, a diverse range of flora thrives here, adapted to survive with minimal water, low temperatures, and high light levels during the summer. This introduction aims to shed light on the resilience and adaptation of Arctic plants, setting the stage for a deeper dive into the unique botanical ecosystem of the Arctic.",
    "Arctic Plant Adaptations": "Plants in the Arctic have developed unique adaptations to endure the extreme climate. Perennial growth, antifreeze proteins, and a short growth cycle are among the evolutionary solutions. These adaptations not only allow the plants to survive but also to reproduce in short summer months. Arctic plants often have small, dark leaves to absorb maximum sunlight, and some species grow in cushion or mat forms to resist cold winds. Understanding these adaptations provides insights into the resilience of Arctic flora.",
    "The Tundra Biome": "The Arctic tundra is a vast, treeless biome where the subsoil is permanently frozen. Here, the vegetation is predominantly composed of dwarf shrubs, grasses, mosses, and lichens. The tundra supports a surprisingly rich biodiversity, adapted to its cold, dry, and windy conditions. The biome plays a crucial role in the Earth's climate system, acting as a carbon sink. However, it's sensitive to climate change, with thawing permafrost and shifting vegetation patterns.",
    "Arctic Plant Biodiversity": "Despite the challenging environment, the Arctic boasts a significant variety of plant species, each adapted to its niche. From the colorful blooms of Arctic poppies to the hardy dwarf willows, these plants form a complex ecosystem. The biodiversity of Arctic flora is vital for local wildlife, providing food and habitat. This diversity also has implications for Arctic peoples, who depend on certain plant species for food, medicine, and materials.",
    "Climate Change and Arctic Flora": "Climate change poses a significant threat to Arctic botany, with rising temperatures, melting permafrost, and changing precipitation patterns. These changes can lead to shifts in plant distribution, phenology, and the composition of the Arctic flora. Some species may thrive, while others could face extinction. This dynamic is critical to understanding future Arctic ecosystems and their global impact, including feedback loops that may exacerbate global warming.",
    "Research and Conservation in the Arctic": "Research in Arctic botany is crucial for understanding the intricate balance of this ecosystem and the impacts of climate change. Scientists conduct studies on plant physiology, genetics, and ecosystem dynamics. Conservation efforts are focused on protecting the Arctic's unique biodiversity through protected areas, sustainable management practices, and international cooperation. These efforts aim to preserve the Arctic flora for future generations and maintain its role in the global climate system.",
    "Traditional Knowledge and Arctic Botany": "Indigenous peoples of the Arctic have a deep connection with the land and its plant life. Traditional knowledge, passed down through generations, includes the uses of plants for nutrition, healing, and materials. This body of knowledge is invaluable for both conservation and understanding the ecological relationships in Arctic ecosystems. Integrating traditional knowledge with scientific research enriches our comprehension of Arctic botany and enhances conservation strategies.",
    "Future Directions in Arctic Botanical Studies": "The future of Arctic botany lies in interdisciplinary research, combining traditional knowledge with modern scientific techniques. As the Arctic undergoes rapid changes, understanding the ecological, cultural, and climatic dimensions of Arctic flora becomes increasingly important. Future research will need to address the challenges of climate change, explore the potential for Arctic plants in biotechnology, and continue to conserve this unique biome. The resilience of Arctic flora offers lessons in adaptation and survival relevant to global challenges."
}
arctic_botany_chunks = list(arctic_botany_dict.values())

# %% [markdown]
# ## Step 1. Start ColBERT Configuration and create embeddings

# %%
from ragstack_colbert import ColbertEmbeddingModel, ChunkData
# colbert stuff starts
colbert = ColbertEmbeddingModel()

chunks = [ChunkData(text=text, metadata={}) for text in arctic_botany_chunks]

embedded_chunks = colbert.embed_chunks(chunks=chunks, doc_id="arctic botany")
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# WARNING: faiss must be imported for indexing
# artifact.metadata:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/405 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [May 01, 13:47:42] Loading segmented_maxsim_cpp extension (set COLBERT_LOAD_TORCH_EXTENSION_VERBOSE=True for more info)...
# /usr/local/lib/python3.10/dist-packages/torch/cuda/amp/grad_scaler.py:126: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(

# %% [markdown]
# Examine the embeddings

# %%
assert len(embedded_chunks) == 8

# %% [markdown]
# ## Step 2. Ingest embeddings and create index on Astra
#
# Connect to Astra including table and index creation

# %%
from ragstack_colbert import CassandraVectorStore
from getpass import getpass
import cassio

keyspace="default_keyspace"
database_id=getpass("Enter your Astra Database Id:")
astra_token=getpass("Enter your Astra Token:")

cassio.init(token=astra_token, database_id=database_id, keyspace=keyspace)
session=cassio.config.resolve_session()

db = CassandraVectorStore(
    keyspace = keyspace,
    table_name="colbert_embeddings4",
    session = session,
)
# Out:
# Enter your Astra Database Id:··········
# Enter your Astra Token:··········
# WARNING:cassandra.cluster:Downgrading core protocol version from 66 to 65 for ac1131b4-60fe-4931-9ff5-73250a163e2f-us-east-1.db.astra.datastax.com:29042:02ce5866-9e2c-4b58-afe4-680df4d8b91f. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# WARNING:cassandra.cluster:Downgrading core protocol version from 65 to 5 for ac1131b4-60fe-4931-9ff5-73250a163e2f-us-east-1.db.astra.datastax.com:29042:02ce5866-9e2c-4b58-afe4-680df4d8b91f. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# ERROR:cassandra.connection:Closing connection <LibevConnection(138950361371920) ac1131b4-60fe-4931-9ff5-73250a163e2f-us-east-1.db.astra.datastax.com:29042:02ce5866-9e2c-4b58-afe4-680df4d8b91f> due to protocol error: Error from server: code=000a [Protocol error] message="Beta version of the protocol used (5/v5-beta), but USE_BETA flag is unset"
# WARNING:cassandra.cluster:Downgrading core protocol version from 5 to 4 for ac1131b4-60fe-4931-9ff5-73250a163e2f-us-east-1.db.astra.datastax.com:29042:02ce5866-9e2c-4b58-afe4-680df4d8b91f. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version

# %% [markdown]
# Indexing embeddings in Astra

# %%
db.put_chunks(chunks=embedded_chunks, delete_existing=True)

# %% [markdown]
# ## Step 3. Retrieval
#
# Create a RAGStack retriever and start asking questions on the indexed embeddings. The library provides
# * Embed query tokens
# * Generate candidate documents using Astra ANN search
# * max similarity scoring
# * Ranking

# %%
import logging
import nest_asyncio
nest_asyncio.apply()

logging.getLogger('cassandra').setLevel(logging.ERROR) # workaround to suppress logs
from ragstack_colbert import ColbertRetriever
retriever = ColbertRetriever(
    vector_store=db, embedding_model=colbert
)

answers = retriever.retrieve("What's artic botany", k=2)
for answer in answers:
  print(f"Rank: {answer.rank} Score: {answer.score} Text: {answer.data.text}\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Rank: 1 Score: 35.225955963134766 Text: Arctic botany is the study of plant life in the Arctic, a region characterized by extreme cold, permafrost, and minimal sunlight for much of the year. Despite these harsh conditions, a diverse range of flora thrives here, adapted to survive with minimal water, low temperatures, and high light levels during the summer. This introduction aims to shed light on the resilience and adaptation of Arctic plants, setting the stage for a deeper dive into the unique botanical ecosystem of the Arctic.
#
# Rank: 1 Score: 29.655662536621094 Text: Research in Arctic botany is crucial for understanding the intricate balance of this ecosystem and the impacts of climate change. Scientists conduct studies on plant physiology, genetics, and ecosystem dynamics. Conservation efforts are focused on protecting the Arctic's unique biodiversity through protected areas, sustainable management practices, and international cooperation. These efforts aim to preserve the Arctic flora for future generations and maintain its role in the global climate system.

# %% [markdown]
# ## 4. LangChain retriever

# %%
# !pip install ragstack-ai-langchain[colbert]
# Out:
# Requirement already satisfied: ragstack-ai-langchain[colbert] in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: astrapy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-langchain[colbert]) (1.1.0)
# Requirement already satisfied: cassio<0.2.0,>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-langchain[colbert]) (0.1.7)
# Requirement already satisfied: langchain==0.1.16 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-langchain[colbert]) (0.1.16)
# Requirement already satisfied: langchain-astradb==0.2.0 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-langchain[colbert]) (0.2.0)
# Requirement already satisfied: langchain-community==0.0.34 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-langchain[colbert]) (0.0.34)
# Requirement already satisfied: langchain-core==0.1.45 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-langchain[colbert]) (0.1.45)
# Requirement already satisfied: langchain-openai==0.1.3 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-langchain[colbert]) (0.1.3)
# Requirement already satisfied: unstructured==0.12.5 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-langchain[colbert]) (0.12.5)
# Requirement already satisfied: ragstack-ai-colbert==1.0.0 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-langchain[colbert]) (1.0.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (0.6.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (1.33)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (0.1.51)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (2.7.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.1.16->ragstack-ai-langchain[colbert]) (8.2.3)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core==0.1.45->ragstack-ai-langchain[colbert]) (23.2)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from langchain-openai==0.1.3->ragstack-ai-langchain[colbert]) (1.23.6)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-openai==0.1.3->ragstack-ai-langchain[colbert]) (0.6.0)
# Requirement already satisfied: colbert-ai==0.2.19 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (0.2.19)
# Requirement already satisfied: pyarrow==14.0.1 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (14.0.1)
# Requirement already satisfied: torch==2.2.1 in /usr/local/lib/python3.10/dist-packages (from ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2.2.1+cu121)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (5.2.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (1.2.0)
# Requirement already satisfied: python-magic in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (0.4.27)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (4.9.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (0.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (4.12.3)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (2.11.1)
# Requirement already satisfied: python-iso639 in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (2024.4.27)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (1.0.9)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (3.8.1)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (2.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (4.11.0)
# Requirement already satisfied: unstructured-client>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (0.22.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured==0.12.5->ragstack-ai-langchain[colbert]) (1.14.1)
# Requirement already satisfied: bitarray in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2.9.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2.19.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2.2.5)
# Requirement already satisfied: git-python in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (1.0.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (1.0.1)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (1.11.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (4.66.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (4.40.0)
# Requirement already satisfied: ujson in /usr/local/lib/python3.10/dist-packages (from colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (5.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (3.13.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (12.4.127)
# Requirement already satisfied: bson<0.6.0,>=0.5.10 in /usr/local/lib/python3.10/dist-packages (from astrapy<2,>=1->ragstack-ai-langchain[colbert]) (0.5.10)
# Requirement already satisfied: deprecation<2.2.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from astrapy<2,>=1->ragstack-ai-langchain[colbert]) (2.1.0)
# Requirement already satisfied: httpx[http2]<1,>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from astrapy<2,>=1->ragstack-ai-langchain[colbert]) (0.27.0)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from astrapy<2,>=1->ragstack-ai-langchain[colbert]) (0.10.2)
# Requirement already satisfied: uuid6<2024.2.0,>=2024.1.12 in /usr/local/lib/python3.10/dist-packages (from astrapy<2,>=1->ragstack-ai-langchain[colbert]) (2024.1.12)
# Requirement already satisfied: cassandra-driver<4.0.0,>=3.28.0 in /usr/local/lib/python3.10/dist-packages (from cassio<0.2.0,>=0.1.4->ragstack-ai-langchain[colbert]) (3.29.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16->ragstack-ai-langchain[colbert]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16->ragstack-ai-langchain[colbert]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16->ragstack-ai-langchain[colbert]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16->ragstack-ai-langchain[colbert]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16->ragstack-ai-langchain[colbert]) (1.9.4)
# Requirement already satisfied: python-dateutil>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from bson<0.6.0,>=0.5.10->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (2.8.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bson<0.6.0,>=0.5.10->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (1.16.0)
# Requirement already satisfied: geomet<0.3,>=0.1 in /usr/local/lib/python3.10/dist-packages (from cassandra-driver<4.0.0,>=3.28.0->cassio<0.2.0,>=0.1.4->ragstack-ai-langchain[colbert]) (0.2.1.post1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.16->ragstack-ai-langchain[colbert]) (3.21.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.16->ragstack-ai-langchain[colbert]) (0.9.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (1.3.1)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.16->ragstack-ai-langchain[colbert]) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.16->ragstack-ai-langchain[colbert]) (3.10.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.1.3->ragstack-ai-langchain[colbert]) (1.7.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.1.16->ragstack-ai-langchain[colbert]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.1.16->ragstack-ai-langchain[colbert]) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.1.16->ragstack-ai-langchain[colbert]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.1.16->ragstack-ai-langchain[colbert]) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.16->ragstack-ai-langchain[colbert]) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.5.2->langchain-openai==0.1.3->ragstack-ai-langchain[colbert]) (2023.12.25)
# Requirement already satisfied: deepdiff>=6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured==0.12.5->ragstack-ai-langchain[colbert]) (7.0.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured==0.12.5->ragstack-ai-langchain[colbert]) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured==0.12.5->ragstack-ai-langchain[colbert]) (1.0.0)
# Requirement already satisfied: pypdf>=4.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client>=0.15.1->unstructured==0.12.5->ragstack-ai-langchain[colbert]) (4.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured==0.12.5->ragstack-ai-langchain[colbert]) (2.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured==0.12.5->ragstack-ai-langchain[colbert]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured==0.12.5->ragstack-ai-langchain[colbert]) (1.4.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (1.2.1)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from deepdiff>=6.0->unstructured-client>=0.15.1->unstructured==0.12.5->ragstack-ai-langchain[colbert]) (4.1.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<2,>=1->ragstack-ai-langchain[colbert]) (4.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (0.70.16)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (0.22.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (3.0.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2.1.5)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.10/dist-packages (from git-python->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (3.1.43)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.2.1->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (1.3.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (0.4.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython->git-python->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (4.0.11)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (2024.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython->git-python->colbert-ai==0.2.19->ragstack-ai-colbert==1.0.0->ragstack-ai-langchain[colbert]) (5.0.1)

# %%
from ragstack_langchain.colbert import ColbertLCRetriever

lc_retriever = ColbertLCRetriever(retriever, k=2)
docs = lc_retriever.get_relevant_documents("what kind fish lives shallow coral reefs atlantic, india ocean, red sea, gulf of mexico, pacific, and arctic ocean")
print(f"first answer: {docs[0].page_content}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# first answer: Despite the challenging environment, the Arctic boasts a significant variety of plant species, each adapted to its niche. From the colorful blooms of Arctic poppies to the hardy dwarf willows, these plants form a complex ecosystem. The biodiversity of Arctic flora is vital for local wildlife, providing food and habitat. This diversity also has implications for Arctic peoples, who depend on certain plant species for food, medicine, and materials.
